# %%
import numpy as np
import math

n = 6
while n < 2000:
    a = n*(n-1)*(n-2)*(n-3)*(n-4)
    b = math.sqrt(a)
    print(isinstance(b, int))
    n += 1
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
import numpy as np
import math

n = 6
while n < 2000:
    a = n*(n-1)*(n-2)*(n-3)*(n-4)
    b = math.sqrt(a)
    print(b)
    n += 1
# Out:
# 26.832815729997478
# 50.19960159204453
# 81.97560612767678
# 122.96340919151518
# 173.89652095427326
# 235.457002444183
# 308.2855818879631
# 392.98854945150754
# 490.14283632426987
# 600.2999250374766
# 723.988950191921
# 861.7192118085798
# 1013.9822483653252
# 1181.2535714231724
# 1363.9941348847508
# 1562.6515926462944
# 1777.6613850787219
# 2009.4476853105682
# 2258.424229413066
# 2524.9950495000976
# 2809.5551249263644
# 3112.490963842305
# 3434.1811251010045
# 3774.9966887402697
# 4135.301681860708
# 4515.453465600105
# 4915.803088000983
# 5336.695606833877
# 5778.470385837415
# 6241.461367340184
# 6725.997323817487
# 7232.402090592032
# 7760.994781598555
# 8312.089989888223
# 8885.99797434143
# 9483.024833880801
# 10103.472670324792
# 10747.639740891951
# 11415.820601253332
# 12108.306239932983
# 12825.384204771412
# 13567.338722092849
# 14334.450809152055
# 15126.998380379368
# 15945.25634789231
# 16789.496716697617
# 17659.988674968055
# 18556.998679743447
# ...
